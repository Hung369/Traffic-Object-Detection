# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 873.6/873.6 kB 5.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Training_YOLO
# Out:
# /content/drive/MyDrive/Training_YOLO

# %%
from ultralytics import YOLO
import locale
locale.getpreferredencoding = lambda: "UTF-8" #convert locale to UTF8 format
from IPython.display import HTML
from base64 import b64encode

# %%
# Load a model
model = YOLO('yolov8n.pt')

# Train model
results = model.train(data="/content/drive/MyDrive/Training_YOLO/addition/data.yaml", epochs=5, imgsz=640, device=0, save=True)
# Out:
# Ultralytics YOLOv8.2.98 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/Training_YOLO/runs/detect/train/weights/last.pt') # continue training on addition dataset
results = model.train(data="/content/drive/MyDrive/Training_YOLO/addition/data.yaml", epochs=10, imgsz=640, device=0, save=True)
# Out:
# Ultralytics YOLOv8.2.98 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
model = YOLO('/content/drive/MyDrive/Training_YOLO/runs/detect/train2/weights/last.pt') # continue training on addition dataset
results = model.train(data="/content/drive/MyDrive/Training_YOLO/addition/data.yaml", epochs=3, imgsz=640, device=0, save=True)
# Out:
# Ultralytics YOLOv8.2.98 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
# %cd /content/
# Out:
# /content

# %%
# Run inference on a video
# Load a model
model = YOLO('/content/drive/MyDrive/Training_YOLO/runs/detect/train3/weights/best.pt')
results = model.predict(source="/content/drive/MyDrive/Training_YOLO/test_video_1.mp4", show=True, save=True)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/3000) /content/drive/MyDrive/Training_YOLO/test_video_1.mp4: 384x640 5 cars, 9.2ms
# video 1/1 (frame 2/3000) /content/drive/MyDrive/Training_YOLO/test_video_1.mp4: 384x640 5 cars, 7.4ms
# video 1/1 (frame 3/3000) /content/drive/MyDrive/Training_YOLO/test_video_1.mp4: 384x640 5 cars, 9.1ms
# ...

# %%
# Run inference on a 2nd video
model = YOLO('/content/drive/MyDrive/Training_YOLO/runs/detect/train3/weights/best.pt')
results = model.predict(source="/content/drive/MyDrive/Training_YOLO/test_video_2.mp4", show=True, save=True)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/1634) /content/drive/MyDrive/Training_YOLO/test_video_2.mp4: 384x640 1 Person, 1 bicycle, 8.6ms
# video 1/1 (frame 2/1634) /content/drive/MyDrive/Training_YOLO/test_video_2.mp4: 384x640 1 Bus, 1 Person, 1 bicycle, 7.4ms
# ...

# %%
# !ffmpeg -i /content/runs/detect/predict2/test_video_1.avi output1.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
# !ffmpeg -i /content/runs/detect/predict3/test_video_2.avi output2.mp4
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
# Display the results video
mp4 = open('output1.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

HTML("""
<video controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)

# %%
mp4 = open('output2.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()

HTML("""
<video controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
